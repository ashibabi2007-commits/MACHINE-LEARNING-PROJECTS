# %%
#importing pandas library for file manipulation
import pandas as pd

# %%
#importing numpy library for numerical manipulation
import numpy as np

# %%
#loading dataset into workspace
df=pd.read_csv(r"C:\Users\ashib\Downloads\electric_car_dataset_15000_rows.csv")
df
# Out:
#         Company      Model Country_of_Purchase  Mileage_per_Charge_Miles  \
# 0          Audi  Q4 e-tron         Netherlands                       416
# 1           Kia        EV6              Canada                       302
# 2         Tesla    Model S              Norway                       388
# 3         Tesla    Model X           Australia                       403
# 4        Nissan       Leaf                 UAE                       307
# ...         ...        ...                 ...                       ...
# 14995      Audi  Q4 e-tron                  UK                       358
# 14996       BMW         i3           Australia                       263
# 14997  Mercedes        EQA               India                       205
# 14998        MG     MG4 EV                  UK                       399
# 14999       BYD    Dolphin               China                       267
#
#        Battery_kWh  Price_USD  Units_Sold  Customer_Rating_Out_of_5  \
# ...

# %%
#checking for data information like type and size all
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   15000 non-null  object
#  1   Model                     15000 non-null  object
#  2   Country_of_Purchase       15000 non-null  object
#  3   Mileage_per_Charge_Miles  15000 non-null  int64
#  4   Battery_kWh               15000 non-null  int64
#  5   Price_USD                 15000 non-null  int64
#  6   Units_Sold                15000 non-null  int64
#  7   Customer_Rating_Out_of_5  15000 non-null  float64
#  8   Recommended_for_Use       15000 non-null  object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.0+ MB

# %%
#checking is there any null values present or not
df.isnull().sum()
# Out:
# Company                     0
# Model                       0
# Country_of_Purchase         0
# Mileage_per_Charge_Miles    0
# Battery_kWh                 0
# Price_USD                   0
# Units_Sold                  0
# Customer_Rating_Out_of_5    0
# Recommended_for_Use         0
# dtype: int64

# %%
#coverting recommend for use to numeric datatype by using yes for 1 and no for 0
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Recommended_for_Use"] = le.fit_transform(df["Recommended_for_Use"])

# %%
#checking the dataset changed or not
df
# Out:
#         Company      Model Country_of_Purchase  Mileage_per_Charge_Miles  \
# 0          Audi  Q4 e-tron         Netherlands                       416
# 1           Kia        EV6              Canada                       302
# 2         Tesla    Model S              Norway                       388
# 3         Tesla    Model X           Australia                       403
# 4        Nissan       Leaf                 UAE                       307
# ...         ...        ...                 ...                       ...
# 14995      Audi  Q4 e-tron                  UK                       358
# 14996       BMW         i3           Australia                       263
# 14997  Mercedes        EQA               India                       205
# 14998        MG     MG4 EV                  UK                       399
# 14999       BYD    Dolphin               China                       267
#
#        Battery_kWh  Price_USD  Units_Sold  Customer_Rating_Out_of_5  \
# ...

# %%
#input and output deciding
x=df[['Mileage_per_Charge_Miles','Battery_kWh','Price_USD','Units_Sold','Customer_Rating_Out_of_5']]
y=df['Recommended_for_Use']

# %%
#splitting dagtaset for training and testing set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#training using a model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#predicting pred = model.
pred=model.predict(X_test)

# %%
#finding accuracy
from sklearn.metrics import r2
accuracy=accuracy_score(X_train,X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 3
#       1 #finding accuracy
#       2 from sklearn.metrics import accuracy_score
# ----> 3 accuracy=accuracy_score(X_train,X_test)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...
