# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ashib\OneDrive\Desktop\Pearson.csv")
df
# Out:
#       Father   Son
# 0       65.0  59.8
# 1       63.3  63.2
# 2       65.0  63.3
# 3       65.8  62.8
# 4       61.1  64.3
# ...      ...   ...
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0
#
# [1078 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Father    0
# Son       0
# dtype: int64

# %%
df.describe()
# Out:
#             Father          Son
# count  1078.000000  1078.000000
# mean     67.686827    68.684230
# std       2.745827     2.816194
# min      59.000000    58.500000
# 25%      65.800000    66.900000
# 50%      67.800000    68.600000
# 75%      69.600000    70.500000
# max      75.400000    78.400000

# %%
x=df[['Father']]
y=df[['Son']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       Father
# 875     64.4
# 949     66.9
# 618     72.0
# 881     67.4
# 590     65.8
# ...      ...
# 330     67.3
# 466     67.6
# 121     69.2
# 1044    69.3
# 860     65.3
#
# [862 rows x 1 columns]

# %%
X_test
# Out:
#       Father
# 423     73.9
# 548     67.9
# 837     67.8
# 587     72.8
# 864     65.0
# ...      ...
# 1046    70.2
# 913     64.6
# 679     67.3
# 409     70.5
# 275     67.3
#
# [216 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[0.51076287]])

# %%
lr.intercept_
# Out:
# array([34.15131538])

# %%
plt.scatter(x,y,color='green',label='Actual_data')
plt.plot(X_train, lr.predict(X_train), color='red',label='Regression Line')
plt.title('Linear Regression Results')
plt.xlabel('FATHER')
plt.ylabel('SON')
plt.legend()
plt.show()

# %%
score = lr.score(X_test,y_test)
print("Accuracy Score is:-",score * 100)
# Out:
# Accuracy Score is:- 26.784157787744057
