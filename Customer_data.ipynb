# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ashib\OneDrive\Desktop\customer_data.csv",usecols=['education','loyalty_status','promotion_usage'],skiprows=[500,15000])
df
# Out:
#         education loyalty_status  promotion_usage
# 0        Bachelor           Gold                0
# 1         Masters        Regular                1
# 2        Bachelor         Silver                0
# 3      HighSchool        Regular                0
# 4         College        Regular                1
# ...           ...            ...              ...
# 99993     College        Regular                0
# 99994  HighSchool        Regular                0
# 99995     College        Regular                0
# 99996    Bachelor        Regular                1
# 99997     College         Silver                0
#
# [99998 rows x 3 columns]

# %%
df.sample(5)
# Out:
#       education loyalty_status  promotion_usage
# 61034  Bachelor        Regular                0
# 96852   Masters         Silver                0
# 38801  Bachelor        Regular                0
# 33937  Bachelor        Regular                0
# 29874   Masters           Gold                1

# %%
df.isnull().sum()
# Out:
# education          0
# loyalty_status     0
# promotion_usage    0
# dtype: int64

# %%
df=df[df['education']!='College']
df
# Out:
#         education loyalty_status  promotion_usage
# 0        Bachelor           Gold                0
# 1         Masters        Regular                1
# 2        Bachelor         Silver                0
# 3      HighSchool        Regular                0
# 5        Bachelor         Silver                0
# ...           ...            ...              ...
# 99989    Bachelor        Regular                0
# 99990  HighSchool         Silver                0
# 99992  HighSchool        Regular                0
# 99994  HighSchool        Regular                0
# 99996    Bachelor        Regular                1
#
# [60126 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#         education loyalty_status
# 93173     Masters        Regular
# 62497    Bachelor         Silver
# 15266    Bachelor         Silver
# 23601     Masters         Silver
# 15950  HighSchool        Regular
# ...           ...            ...
# 76898  HighSchool        Regular
# 78546     Masters        Regular
# 82198    Bachelor        Regular
# 61322  HighSchool         Silver
# 16310     Masters        Regular
#
# [48100 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['HighSchool','Bachelor','Masters'],['Regular','Silver','Gold']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['HighSchool', 'Bachelor', 'Masters'],
#                            ['Regular', 'Silver', 'Gold']])

# %%
X_train['education'].unique()
# Out:
# array(['HighSchool', 'Bachelor', 'Masters'], dtype=object)

# %%
X_train['loyalty_status'].unique()
# Out:
# array(['Silver', 'Gold', 'Regular'], dtype=object)

# %%
X_train=oe.transform(X_train)

# %%
X_test=oe.transform(X_test)

# %%
X_train
# Out:
# array([[2., 0.],
#        [1., 1.],
#        [1., 1.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [2., 0.]], shape=(48100, 2))

# %%
oe.categories_
# Out:
# [array(['HighSchool', 'Bachelor', 'Masters'], dtype=object),
#  array(['Regular', 'Silver', 'Gold'], dtype=object)]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array([0, 1])

# %%
y_train=le.transform(y_train)
y_test=le.transform(y_test)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 1], shape=(48100,))
